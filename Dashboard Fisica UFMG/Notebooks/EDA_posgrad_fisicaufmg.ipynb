# %% [markdown]
# <div align="left">
#     <h1> <font color="#cb1027"> Análise Exploratória dos Dados</font> </h1>
#
# <div align="center">
#     <img src="https://www.fisica.ufmg.br/wp-content/uploads/2017/09/logo_df_fisica_ufmg.jpg"></img>
# </div>
#
# </div>
#
# **Autor: João Victor Campos**
#
# ---
#
# > Os dados do presente Jupyter Notebook foram previamente obtidos e tratados em outro Jupyter Notebook em: **[ETL-dados.ipynb](./ETL-dados.ipynb)**
# > <font color="#cb1027"> Fonte: </font>  [Departamento de Física - UFMG | Corpo Discente do 2º semestre de 2025]("https://www.fisica.ufmg.br/posgraduacao/corpo-discente/")
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from highlight_text import fig_text, ax_text

# Datas pt-BR
import locale
locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')

IMG_PATH = "./img"

# %%
# Carregando os dados limpos.
pos_grad = pd.read_csv("fisica-ufmg.csv")

# %% [markdown]
# ## <font color="#cb1027"> Configurações Gerais de Estilo </font>

# %%
from pyfonts import load_google_font

# --- Fontes
font = load_google_font("Montserrat")
boldfont = load_google_font("Montserrat", weight="bold")
digit_font = load_google_font("Lato", weight="bold")

config = {
    'figure.facecolor': 'whitesmoke',
    'axes.facecolor': 'whitesmoke',
}

plt.rcParams.update(config)

# %%
def apply_tick_fonts(ax, *, font=font):
    for a in ax:
        for text in (*a.get_xticklabels(),*a.get_yticklabels()):
            if text is not None:
                text.set_fontproperties(font)

# %% [markdown]
# ---

# %% [markdown]
# ## <font color="#cb1027">Visão Geral do Programa</font>

# %%
ct_modalidade_area = pd.crosstab(index=pos_grad["modalidade"],columns=pos_grad["area"])

# Ordenando pela maior quantidade
sorted_idx: pd.Index = ct_modalidade_area.sum().sort_values(ascending=False).index
ct_modalidade_area = ct_modalidade_area[sorted_idx]

ct_modalidade_area
# Out:
# area        Física  Física Aplicada e Interdisciplinar  Astrofísica
# modalidade
# Doutorado       77                                   0            6
# Mestrado        41                                  19            9

# %%
count_alunos: pd.Series = pos_grad["modalidade"].value_counts()
count_areas: pd.Series = pos_grad["area"].value_counts()

print(f"Número Total de Alunos do Programa: {count_alunos.sum()}")
print(count_alunos)

print(f"Contagem das Áreas de Concentração do Programa: {count_areas.size, count_areas.index.tolist()}")
# Out:
# Número Total de Alunos do Programa: 152
# modalidade
# Doutorado    83
# Mestrado     69
# Name: count, dtype: int64
# Contagem das Áreas de Concentração do Programa: (3, ['Física', 'Física Aplicada e Interdisciplinar', 'Astrofísica'])

# %%
RED_DF = "#d43c4f"
BLUE_DF = "#384572"

fig, axs = plt.subplots(
    2,
    2,
    figsize=(8, 5),
    dpi=300,
    gridspec_kw=dict(height_ratios=[1, 4], hspace=0.2),
    layout="constrained",
)
ax1, ax2, ax3, ax4 = axs.flatten()

fig.suptitle("Visão Geral do Programa", font=boldfont, size=28, color="#000000")


# --- AX1 ---
ax1.text(
    x=0.5,
    y=0.5,
    s=f"{count_alunos.sum()}",
    transform=ax1.transAxes,
    ha="center",
    va="center",
    size=24,
    font=boldfont,
    color=BLUE_DF,
)
ax1.text(
    x=0.5,
    y=0.2,
    s="Alunos Matriculados",
    transform=ax1.transAxes,
    ha="center",
    va="center",
    size=18,
    font=font,
    color=BLUE_DF,
)
ax1.set_axis_off()
# --- AX2 ---
cores = {"Doutorado": "#23526d", "Mestrado": "#2e6f95"}
ax2.text(
    x=0.2,
    y=0.5,
    s=f"{count_alunos.Doutorado / count_alunos.sum():.0%}",
    transform=ax2.transAxes,
    ha="center",
    va="center",
    size=24,
    font=boldfont,
    color=cores["Doutorado"],
)
ax2.text(
    x=0.2,
    y=0.2,
    s="Doutorado",
    transform=ax2.transAxes,
    ha="center",
    va="center",
    size=18,
    font=font,
    color=cores["Doutorado"],
)

ax2.text(
    x=0.7,
    y=0.5,
    s=f"{count_alunos.Mestrado / count_alunos.sum():.0%}",
    transform=ax2.transAxes,
    ha="center",
    va="center",
    size=24,
    font=boldfont,
    color="#2e6f95",
)
ax2.text(
    x=0.7,
    y=0.2,
    s="Mestrado",
    transform=ax2.transAxes,
    ha="center",
    va="center",
    size=18,
    font=font,
    color="#2e6f95",
)
ax2.set_axis_off()


# --- AX3 ---
ax3.set_title("Alunos por Modalidade", font=boldfont)
colors = ["#E0AC2B", "#E85252", "#6689C6"]
sns.despine(left=True, ax=ax3)
ct_modalidade_area.plot(
    kind="bar", stacked=True, ax=ax3, legend=False, rot=0, color=colors[::-1]
)
# ax3.bar(x=ct_modalidade_area.index, height=ct_modalidade_ar)
ax3.set_yticks([])
ax3.set_xlabel("")
ax3.spines["bottom"].set(color="dimgray")
ax3.legend(
    labels=["Física", "FAI", "Astrofísica"],
    bbox_to_anchor=(0.75, 0.9),
    frameon=False,
    reverse=True,
)

text_config = [
    dict(weight="bold", color=cores["Doutorado"]),
    dict(weight="bold", color=colors[1]),
]
ax_text(
    x=-0.3,
    y=98,
    s="O <Doutorado> não possui\n <Física Aplicada (FAI)>",
    highlight_textprops=text_config,
    ax=ax3,
    size=8,
)
for i, bar_container in enumerate(ax3.containers):
    ax3.bar_label(
        ax3.containers[i],
        label_type="center",
        font=digit_font,
        fmt=lambda x: f"{int(x)}" if x > 0 else "",
        color="white",
    )

# --- AX4 ---
ax4.set_title("Alunos por Área de Concentração", font=boldfont)

ax4.bar(x=count_areas.index, height=count_areas.values, color=colors[::-1], label=["Física", "FAI", "Astrofísica"])
ax4.bar_label(ax4.containers[0], label_type="center", font=digit_font, color="white")
ax4.set_ylabel("")
ax4.set_xlabel("")
ax4.set_yticks([])
ax4.spines["bottom"].set(color="dimgray")

ax4.legend(frameon=False)
sns.despine(left=True, ax=ax4)
ax4.set(xticks=[0, 1, 2], xticklabels=["Física", "FAI", "Astrofísica"])

fig.savefig(f"{IMG_PATH}/VisaoGeral_DF.png", bbox_inches="tight")
apply_tick_fonts(ax=fig.get_axes())
plt.show()

# %% [markdown]
# ### <font color="cb1027">Bolsas no Programa</font>

# %%
ct_modalidade_bolsista = pd.crosstab(
    index=pos_grad["modalidade"],
    columns=pos_grad["bolsista"],
)
display(ct_modalidade_bolsista)
print(ct_modalidade_bolsista.columns)
# Out:
# bolsista    False  True
# modalidade
# Doutorado      20     63
# Mestrado       24     45
# Index([False, True], dtype='bool', name='bolsista')

# %%
ct_modalidade_bolsista= ct_modalidade_bolsista.rename(columns={False: "Não", True: "Sim"})
display(ct_modalidade_bolsista)
print(ct_modalidade_bolsista.columns)

# Mudei os nomes para "Sim" e "Não" para conseguir ordenar as colunas.
# Com dtype bool o ordenamento das barras confunde com as máscaras do Pandas

ct_modalidade_bolsista.sort_index(ascending=False, inplace=True)

# Além disso deixei primeiro Doutorado e depois Mestrado para acompanhar as outras barras

# %%
# Percentual (proportion)
(pos_grad["bolsista"].value_counts(normalize=True) * 100).round(2)

# %%
pos_grad["bolsista"].value_counts()

# %%
ct_modalidade_bolsista

# %%
fig, axs = plt.subplots(
    nrows=2, ncols=2, figsize=(12, 8), dpi=150, layout="constrained"
)
fig.suptitle("Bolsas no Programa", font=boldfont, size=18)
ax1, ax2, ax3, ax4 = axs.flatten()

# --- AX1 ---
# Pie Chart
ax1.set_title("Distribuição de Bolsas")
bolsas_alunos = ct_modalidade_bolsista.sum()
cores = ["#D3D3D3", "#2C5F98"]
wedges, texts, autotexts = ax1.pie(
    bolsas_alunos,
    labels=["Sem Bolsa\n(44)", "Com bolsa\n(108)"],
    colors=cores,
    autopct="%1.f%%",
    startangle=90,
    pctdistance=0.8,
    wedgeprops=dict(width=0.4, edgecolor="w"),  # width=0.4 cria o buraco (Rosca)
)
plt.setp(autotexts, font=digit_font)
autotexts[1].set_color("white")
plt.setp(texts, font=font)

ax1.text(
    0,
    0,
    f"TOTAL\n{bolsas_alunos.sum()}\nAlunos",
    ha="center",
    va="center",
    font=boldfont,
    fontsize=12,
    color="dimgrey",
)

# --- AX2 ---
# Bolsas Mestrado vs Doutorado
ax2.set_title("Distribuições de Bolsas por Modalidade")
ct_modalidade_bolsista[["Sim", "Não"]].plot(
    kind="bar", stacked=True, color=cores[::-1], ax=ax2
)
ax2.tick_params(axis="x", rotation=0)
ax2.set_xlabel("")
ax2.legend(title="Bolsista?",prop=font, title_fontproperties=font)
sns.despine(ax=ax2, left=True)
ax2.set_yticks([])
for i, bar_container in enumerate(ax2.containers):
    ax2.bar_label(
        ax2.containers[i], label_type="center", font=digit_font, color="white"
    )


## --- Barras Mestrado (Esquerda)
mestrado_com_bolsa: int = ct_modalidade_bolsista.loc["Mestrado", "Sim"]  # 45
mestrado_sem_bolsa: int = ct_modalidade_bolsista.loc["Mestrado", "Não"]  # 24
total_mest = mestrado_com_bolsa + mestrado_sem_bolsa

ax2.vlines(x=-0.27, ymin=0, ymax=mestrado_com_bolsa, color=cores[1], lw=2)
ax2.text(
    x=-0.36,
    y=24.5,
    s=f"{mestrado_com_bolsa / (total_mest):.0%}",
    rotation=90,
    color=cores[1],
)
ax2.vlines(x=-0.27, ymin=mestrado_com_bolsa, ymax=total_mest, color=cores[0], lw=2)
ax2.text(
    x=-0.36,
    y=55,
    s=f"{mestrado_sem_bolsa / (total_mest):.0%}",
    rotation=90,
    color=cores[0],
)

## ---  Barras Doutorado (Direita)
doutorado_com_bolsa: int = ct_modalidade_bolsista.loc["Doutorado", "Sim"]  # 63
doutorado_sem_bolsa: int = ct_modalidade_bolsista.loc["Doutorado", "Não"]  # 20
total_doc = doutorado_com_bolsa + doutorado_sem_bolsa
ax2.vlines(x=1.27, ymin=0, ymax=doutorado_com_bolsa, color=cores[1], lw=2)
ax2.text(
    x=1.3,
    y=24.5,
    s=f"{doutorado_com_bolsa / (total_doc):.0%}",
    rotation=90,
    color=cores[1],
)  # Sim
ax2.vlines(x=1.27, ymin=doutorado_com_bolsa, ymax=total_doc, color=cores[0], lw=2)
ax2.text(
    x=1.3,
    y=71,
    s=f"{doutorado_sem_bolsa / (total_doc):.0%}",
    rotation=90,
    color=cores[0],
)


# --- AX3 ---
# Distribuição de Bolsas por área
bolsistas = pos_grad.query("bolsista == True")
ax3.set_title("Nº de Bolsistas por Área")
sns.despine(left=True, ax=ax3)
sns.countplot(
    data=bolsistas,
    x="modalidade",
    hue="area_de_concentracao",
    palette="Blues_r",
    ax=ax3,
)
ax3.set_ylabel("")
ax3.set_xlabel("")
ax3.set_yticks([])
for i, bar_container in enumerate(ax3.containers):
    ax3.bar_label(
        ax3.containers[i], label_type="center", font=digit_font, color="white", fontweight="bold"
    )
handles, labels = ax3.get_legend_handles_labels()
labels[2] = "FAI"
ax3.legend(handles=handles, labels=labels, title="", frameon=False, loc="upper left")

# --- AX4 ---
# Cobertura de Bolsas por Área (%)
ax4.set_title("Cobertura de Alunos com Bolsa (%)")
sns.barplot(
    data=pos_grad,
    x="modalidade",
    y="bolsista",
    hue="area_de_concentracao",
    palette="Blues_r",
    errorbar=None,
    ax=ax4,
)
ax4.set_xlabel("")
ax4.set_ylabel("")
for i, bar_container in enumerate(ax4.containers):
    ax4.bar_label(
        ax4.containers[i],
        label_type="center",
        font=digit_font,
        color="white",
        fmt=lambda x: f"{x:.0%}",
    )
ax4.set_yticks([])
handles, labels = ax4.get_legend_handles_labels()
labels[2] = "FAI"
ax4.legend(handles=handles, labels=labels, title="", ncols=3, loc="upper center", prop=font)
sns.despine(left=True, ax=ax4)
# ---

apply_tick_fonts(ax=fig.get_axes())
fig.savefig(f"{IMG_PATH}/BolsasDaPG.png", format="png", bbox_inches="tight")


plt.show()

# %% [markdown]
# ### <font color="#384572"> Estrutura de Fomento</font>

# %%
pos_grad["agencia"].unique()

# %%
# Deixar uma coluna apenas com CAPES, CNPQ e FAPEMIG e outra auxiliar com PRPG.
pos_grad["agencia_unica"] = pos_grad["agencia"].str.split("/").str[0]

# Criar uma coluna auxiliar que contenha informação da PRPG
pos_grad["tipo_bolsa"] = pos_grad["agencia"].apply(lambda x: "PRPG" if "PRPG" in str(x) else "Normal")

# %%
pos_grad[["agencia_unica", "tipo_bolsa"]].sample(10)

# %%
ct_bolsas_agencias = pd.crosstab(
    index=pos_grad["agencia_unica"], columns=pos_grad["tipo_bolsa"]
)
ct_bolsas_agencias

# %%
fig, ax = plt.subplots(figsize=(6, 5), dpi=200)
fig.suptitle("Agências de Fomento", font=boldfont, size=18)
BLUE = "#384572"
LIGHT_BLUE = "#79abc9"
RED = "#c80019"

ct_bolsas_agencias.plot(
    kind="bar",
    stacked=True,
    color=[BLUE, RED],
    rot=0,
    xlabel="",
    ax=ax,
)
for i, _ in enumerate(ax.containers):
    ax.bar_label(
        ax.containers[i],
        label_type="center",
        fmt=lambda x: int(x) if x != 0 else "",
        color="white",
        font=boldfont
    )
sns.despine(left=True, ax=ax)
ax.set_yticks([])
ax.legend(title="", frameon=False)

# ---
# Anotação no Gráfico
total_capes, total_cnpq, total_fapemig = ct_bolsas_agencias.sum(axis=1)
texto = f"CAPES:{total_capes}\nCNPQ:{total_cnpq}\nFAPEMIG:{total_fapemig}"
# ax.text(
#     transform=ax.transAxes,
#     x=0.7,
#     y=0.7,
#     s=texto,
#     # font=font,
#     # fontfamily="DejaVu Sans Mono",
# )

apply_tick_fonts(ax=fig.get_axes())
fig.savefig(f"{IMG_PATH}/AgenciasDeFomento.png", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5), dpi=200)
fig.suptitle("Agências de Fomento", font=boldfont, size=18)
BLUE = "#384572"
RED = "#c80019"

# MUDANÇA: stacked=True para centralizar as barras e mostrar a composição
ct_bolsas_agencias.plot(
    kind="bar",
    stacked=True, 
    color=[BLUE, RED],
    rot=0,
    xlabel="",
    ax=ax,
    width=0.6 # Ajuste opcional para a largura da barra
)

# Rótulos de dados
for i, _ in enumerate(ax.containers):
    ax.bar_label(
        ax.containers[i],
        label_type="center",
        fmt=lambda x: int(x) if x > 0 else "", # Esconde o "0" se não houver bolsa
        color="white",
        fontweight='bold'
    )

sns.despine(left=True, ax=ax)
ax.set_yticks([])
ax.legend(title="", frameon=False, loc='upper right')

# --- Anotação (Mantida conforme seu código) ---
total_capes, total_cnpq, total_fapemig = ct_bolsas_agencias.sum(axis=1)
texto = f"TOTAL\nCAPES: {total_capes}\nCNPQ: {total_cnpq}\nFAPEMIG: {total_fapemig}"
ax.text(
    0.7, 0.65, texto, 
    transform=ax.transAxes, 
    # fontfamily="DejaVu Sans Mono",
    fontsize=10,
    verticalalignment='top'
)

plt.show()

# %% [markdown]
# ### <font color="#384572"> Séries Temporais </font>
